# %% [markdown]
# # **DATA SCIENCE ITINERARY - IT ACADEMY**

# %% [markdown]
# # **Sprint 15. Data Science Tools**

# %% [markdown]
# # Kibana

# %%
# Libraries and modules
from PIL import Image

# %% [markdown]
# # **Exercise 1**
#
# **STATEMENT:** Download Kibana and show some graphs using Example datasets.
#
# TO DOWNLOAD **ELASTICSEARCH** AND **KIBANA** FOR MAC I HAD TO FOLLOW THE COMMANDS OF A VERY SPECIFIC PAGE: https://logz.io/blog/brew-install-elasticsearch-mac/

# %% [markdown]
# WE OPEN **ELASTICSEARCH** FROM THE TERMINAL AND WRITE IN THE BROWSER: http://localhost:9200

# %%
Image.open('/Users/adrianova/Desktop/Data Science/Python/IT Academy - Python/SPRINT 16 - Caixa d_eines per a la ciència de dades/S15 T01_ Visualització interactiva amb ElasticSearch Stack/Images/elasticsearch.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=513x366 at 0x7FAEAA144B20>

# %% [markdown]
# WE OPEN **KIBANA** FROM THE TERMINAL AND WRITE IN THE BROWSER: http://localhost:5601

# %%
Image.open('/Users/adrianova/Desktop/Data Science/Python/IT Academy - Python/SPRINT 16 - Caixa d_eines per a la ciència de dades/S15 T01_ Visualització interactiva amb ElasticSearch Stack/Images/kibana.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=892x916 at 0x7FAEAA1E4C70>

# %% [markdown]
# ## **CHART VISUALIZATIONS**

# %% [markdown]
# OUR DATA SET WILL BE **KIBANA SAMPLE FLIGHTS**.
#
# IN THIS CHART WE WANT TO SHOW THE % OF FLIGHTS THAT ARRIVE ON TIME AT THEIR DESTINATION VS FLIGHTS THAT ARRIVE LATE AT THEIR DESTINATION

# %%
Image.open('/Users/adrianova/Desktop/Data Science/Python/IT Academy - Python/SPRINT 16 - Caixa d_eines per a la ciència de dades/S15 T01_ Visualització interactiva amb ElasticSearch Stack/Images/% Delayed Flights.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1312x752 at 0x7FAEABD4C8B0>

# %% [markdown]
# WE SHOW THE TOTAL MINUTES OF DELAY BY AIRLINE. THERE AREE ONLY 4 AIRLINES IN OUR DATASET

# %%
Image.open('/Users/adrianova/Desktop/Data Science/Python/IT Academy - Python/SPRINT 16 - Caixa d_eines per a la ciència de dades/S15 T01_ Visualització interactiva amb ElasticSearch Stack/Images/Minutes Delayed by Carrier.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=956x254 at 0x7FAEAA17FBB0>

# %% [markdown]
# THE NEXT CHART SHOWS ON THE 'X' AXIS THE TIME AT ORIGIN WHILE THE COLOR INSIDE THE GRAPH SHOWS THE TIME AT DESTINATION. FOR EXAMPLE, WE SEE THAT THERE ARE 350 FLIGHTS WHERE THE ORIGIN IS A 'CLEAR' DAY, BUT AT DESTINATION WE FIND THAT IT IS A 'SUNNY', 'CLEAR', 'RAINY' DAY, ETC.

# %%
Image.open('/Users/adrianova/Desktop/Data Science/Python/IT Academy - Python/SPRINT 16 - Caixa d_eines per a la ciència de dades/S15 T01_ Visualització interactiva amb ElasticSearch Stack/Images/Origin and Destination Weather.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1326x770 at 0x7FAEABD4CF10>

# %% [markdown]
# WE SHOW THE DIFFERENT FLIGHTS AT ORIGIN AND DESTINATION WITH DIFFERENT METRICS SUCH AS: WEATHER, DEPARTURE/ARRIVAL TIME, PRICE OF THE FLIGHT, CITY OF ORIGIN/DESTINATION, ETC.

# %%
Image.open('/Users/adrianova/Desktop/Data Science/Python/IT Academy - Python/SPRINT 16 - Caixa d_eines per a la ciència de dades/S15 T01_ Visualització interactiva amb ElasticSearch Stack/Images/Origin and Destination Flights.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1897x682 at 0x7FAEABD4CC70>

# %% [markdown]
# # **Exercise 2**
#
# **STATEMENT:** Implement a dashboard that interactively displays the data you choose.

# %%
Image.open('/Users/adrianova/Desktop/Data Science/Python/IT Academy - Python/SPRINT 16 - Caixa d_eines per a la ciència de dades/S15 T01_ Visualització interactiva amb ElasticSearch Stack/Images/USA and KibanaAirlines.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1914x817 at 0x7FAEABD4CAC0>

# %% [markdown]
# IN THIS DASHBOARD I HAVE TAKEN THE DATA ONLY FOR FLIGHTS WHICH THE COUNTRY OF ORIGIN IS **UNITED STATES** AND FROM THE COMPANY **KIBANA AIRLINES**.
#
# + WE CAN SEE ON THE MAP HOW THE ORIGIN FLIGHTS APPEAR FROM THE US (BLUE). THOSE THAT APPEAR IN RED MAY BE BECAUSE THEY ARE NATIONAL FLIGHTS.
# + WE CAN SEE THE WEATHER IN ORIGIN/DESTINATION FOR USA FLIGHTS
# + WE CAN SEE THE DELAYED AND CANCELED FOR THOSE ORIGIN FLIGHTS.

# %% [markdown]
# # **Exercise 3**
#
# **STATEMENT:** Implement a dashboard that generates graphics using each of the different types of graphics that Kibana offers.

# %%
Image.open('/Users/adrianova/Desktop/Data Science/Python/IT Academy - Python/SPRINT 16 - Caixa d_eines per a la ciència de dades/S15 T01_ Visualització interactiva amb ElasticSearch Stack/Images/Dashboard2.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1912x846 at 0x7FAEABD4C700>
